# %%
pip install matplotlib

# %%
pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pip install pandas

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:/Users/Hp/OneDrive - National Institute of Technology, Rourkela/Desktop/Python_projects/Project2/Superstore_USA")

# %%
dataset = pd.read_excel(r"C:/Users/Hp/OneDrive - National Institute of Technology, Rourkela/Desktop/Python_projects/Project2/Superstore_USA.xlsx")

# %%
pip install openpyxl

# %%
import openpyxl

# %%
dataset = pd.read_excel("C:/Users/Hp/OneDrive - National Institute of Technology, Rourkela/Desktop/Python_projects/Project2/Superstore_USA.xlsx")

# %%
dataset.head(2)

# %%
dataset.shape

# %%
dataset.isnull().sum()

# %%
dataset['Order Priority'].value_counts(

# %%
dataset['Product Base Margin'].fillna(dataset['Product Base Margin'].mean(),inplace = True)

# %% [markdown]
#  # Data Cleaning

# %%
dataset['Order Priority'].unique()

# %%
dataset['Order Priority'] = dataset['Order Priority'].replace('Critical ', 'Critical')

# %%
dataset['Order Priority'].unique()

# %% [markdown]
# # Order Priority

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = 'Order Priority' , data = dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()

# %% [markdown]
# # Shiping Mode

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize = (5,4))
plt.pie(y,labels = x, startangle = 60, autopct = "%0.2f%%")
plt.title("Shipping Mode Chart")
plt.legend(loc = 2)
plt.show()

# %%
plt.figure(figsize = (5,4))
sns.countplot(x = 'Ship Mode' , data = dataset, hue = "Product Category")
plt.show()

# %% [markdown]
# # Customer Segement

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Customer Segment", data=dataset)
plt.title("Customer Segment")
plt.show()

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x="Product Category", data=dataset,  )
plt.title("Product Category")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Product Category", data=dataset[dataset["Product Category"]=="Office Supplies"], hue= "Product Sub-Category"  )
plt.title("Product Category")
plt.show()

# %% [markdown]
# # Order Year

# %%
dataset["Order Year"] = dataset["Order Date"].dt.year

# %%
dataset["Order Year"].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,4))
sns.countplot(x = "Order Year" , data = dataset)
plt.title("Count of Order Year")
plt.show()

# %% [markdown]
# # category wise Profit

# %%
plt.figure(figsize = (5,4))
sns.barplot(x = "Product Category" ,  y = "Profit", data = dataset, estimator = "sum")
plt.show()

# %% [markdown]
# # state and Province

# %%
dataset["State or Province"].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %% [markdown]
# # Product Based Margin

# %%
plt.figure(figsize = (5,4))
sns.barplot(x = "Product Category" ,  y = "Product Base Margin", data = dataset, estimator = "sum")
plt.show()
